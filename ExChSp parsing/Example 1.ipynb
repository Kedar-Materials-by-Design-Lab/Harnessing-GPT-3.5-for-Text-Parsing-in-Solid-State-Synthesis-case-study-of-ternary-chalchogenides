# %%
import os
import utils
import pandas as pd
import pypdf

# %%
key = "API key"

# %%
#specify foldername here
for root, dirs, files in os.walk('directory_name'):
    break
data_df = pd.DataFrame()

# %%
for ind, i in enumerate(files):
    file_name = 'directory_name/' + i
    print(file_name)
    print(ind, 'of', len(files))
    print('-'*20)
    data_df = pd.concat([data_df, utils.extract_data_v2(file_name, key)])
# Out:
# Andre/1-s2.0-S004060900801064X-main.pdf
# 0 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Andre/1-s2.0-S0925838805012284-main.pdf
# 1 of 20
# --------------------
# Synthesis info:
# Not specified
# YES
# Not specified
# Not specified
# Not specified
#
# Phase info:
# YES
# NA
# Not Specified
# NA
# NA
#
# Base & Dopant info:
# ['AgInSe2','Si']
# ['AgInSe2','Si']
# ['AgInSiSe6','Ag']
# ['NA','NA']
# ['NA','NA']
#
# Temp Profile:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# 40 | K | 40 | K/h | NA | NA
# 1270 | K | NA | NA | NA | NA
# 670 | K | NA | NA | 250 | hour
#
# Check Profile format:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# 40 | K | 40 | K/h | NA | NA
# 1270 | K | NA | NA | NA | NA
# 670 | K | NA | NA | 250 | hour
#
# ...

# %%
data_df.to_csv('result.csv')
data_df
# Out:
#                                       file_name base_compound dopant  \
# 0       Andre/1-s2.0-S0925838805012284-main.pdf       AgInSe2     Si
# 0    Andre/1-s2.0-S1369800115300755-mainext.pdf       AgInSe2     NA
# 0         Andre/1-s2.0-S2542529321000894-am.pdf       AgInSe2     Ag
# 0                        Andre/1173_AthabRH.pdf     AgCuInSe2     Cu
# 0                           Andre/125914181.pdf       TlInSe2     Cu
# 0                    Andre/557f5e1ce06fba06.pdf       AgInSe2     Cu
# 0                      Andre/acsaem.0c02437.pdf       AgInSe2     Ag
# 0  Andre/Adv Elect Materials - 2021 - Zhong.pdf       AgGaTe2     In
# 0                Andre/PIIS254243511730079X.pdf       AgGaSe6     Te
# 0                            Andre/retrieve.pdf       AgGaTe2     NA
# 0                   Andre/s12598-018-1031-0.pdf       AgGaTe2     Cu
#
#    primiary_temperature primiary_duration primiary_ramp_rate  \
# 0                    40                NA               40.0
# ...
