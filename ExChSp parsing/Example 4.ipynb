# %%
import os
import utils
import pandas as pd

# %%
key = 'API KEY'

# %%
import os

your_folder_name = 'Samyak_2'
#specify foldername here
for root, dirs, files in os.walk(your_folder_name):
    break
data_df = pd.DataFrame()

# %%
for ind, i in enumerate(files):
    file_name = your_folder_name +'/' + i
    print(file_name)
    print(ind, 'of', len(files))
    print('-'*20)
    data_df = pd.concat([data_df, utils.extract_data_v2(file_name, key)])
# Out:
# Samyak_2/1-s2.0-S0040603112001426-main.pdf
# 0 of 10
# --------------------
# Synthesis info:
# Not specified
# YES
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
#
# Phase info:
# NA
# NA
# NA
# YES
# No
# NA
# NA
#
# Base & Dopant info:
# ['CuInTe2','Ni']
# ['Tl2Te', 'Bi2Se3']
# ['Tl2Te', 'Bi']
# ['TlBiTeSe', 'Tl']
# ['Tl2Te', 'Bi2Se3']
# ['NA','NA']
# ['NA','NA']
#
# Temp Profile:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# NA | NA | NA | NA | NA | NA
#
# Check Profile format:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit | NA | NA | NA | NA | NA | NA
# Samyak_2/10-5772.pdf
# 1 of 10
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# YES
# Not specified
# YES
# No
# Not specified
# YES
# Not specified
# YES
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
#
# Phase info:
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# YES
# No
# NA
# NA
# NA
# YES
# NA
# NA
# YES
# NA
# NA
#
# Base & Dopant info:
# ['TlTe6','A']
# ['NA','NA']
# ['NA','NA']
# ['NA','NA']
# ['Tl5Te3','Sb and Pb']
# ['NA','NA']
# ['TlSbTe2','AgSbTe']
# ['TlZrTe3','Gd']
# ['TlTe6','Ln']
# ['BiSbTe3', 'Al']
# ['TlSnBiTe6','No dopant mentioned']
# ['TlTe6', 'Pb, Sn, Ca']
# ['TlTe6','Sn']
# ['TlSnTe6', 'Tl']
# ['TlSnTe6','Sn']
# ['TlSnTe6','C']
# ['NA','NA']
# ['TlSbTe6','Sn']
# ['TlSbTe6','Sn']
# ['TlSbSnTe6','Sn']
# ['TlSbTe', 'Sn']
# ['NA','NA']
#
# Temp Profile:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# NA | NA | NA | NA | NA | NA
#
# Check Profile format:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit | NA | NA | NA | NA | NA | NA
# Samyak_2/aem-han.pdf
# 2 of 10
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Samyak_2/app143z1p04.pdf
# 3 of 10
# --------------------
# Synthesis info:
# Not specified
# YES
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
#
# Phase info:
# NA
# NA
# NA
# NA
# NA
# NA
# NA
#
# Base & Dopant info:
# ['TlBiSe2','NA']
# ['TlBiSe2','NA']
# ['TlBiSe2','NA']
# ['NA','NA']
# ['TlBiSe2','NA']
# ['TlBiSe2','NA']
# ['NA','NA']
#
# Temp Profile:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# NA | NA | NA | NA | NA | NA
#
# Check Profile format:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit | NA | NA | NA | NA | NA | NA
# Samyak_2/BF00818967.pdf
# 4 of 10
# --------------------
# Synthesis info:
# YES
# Not specified
#
# Phase info:
# NA
# NA
#
# Base & Dopant info:
# ['T1BiS2', 'T1BiSe2, T1BiTe2']
# ['T1BiTe2','NA']
#
# Temp Profile:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# 300 | K | NA | NA | NA | NA
# 450-500 | K | NA | NA | NA | NA
# 400 | K | NA | NA | NA | NA
#
# Check Profile format:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# 300 | K | NA | NA | NA | NA
# 450-500 | K | NA | NA | NA | NA
# 400 | K | NA | NA | NA | NA
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-53c1a8984ca5> in <module>
#       4     print(ind, 'of', len(files))
#       5     print('-'*20)
# ----> 6     data_df = pd.concat([data_df, utils.extract_data_v2(file_name, key)])
#
# ~\Documents\NTU intern\Final extraction v2\utils.py in extract_data_v2(file_name, key)
#     264                 if 'C' in temp[1]:
#     265                     temperatures += [int(temp[0])+273]
# --> 266                 else:
#     267                     temperatures += [int(temp[0])]
#     268
#
# ValueError: invalid literal for int() with base 10: '450-500'

# %%
data_df
# Out:
#                                            file_name base_compound dopant  \
# 0           Samyak/1-s2.0-S0022024810008985-main.pdf       CuInSe2     Cd
# 0           Samyak/1-s2.0-S092151071200270X-main.pdf       AgInTe2     Ag
# 0           Samyak/1-s2.0-S1385894721033842-main.pdf       CuGaTe2     Ni
# 0           Samyak/1-s2.0-S1452398123021399-main.pdf       CuGaSe2     Ga
# 0           Samyak/1-s2.0-S2352847817300862-main.pdf       CuGaTe2     Fe
# 0                              Samyak/125914182a.pdf       TlGaSe2     Cu
# 0                   Samyak/acs.chemmater.2c01869.pdf       CuGaTe2     Li
# 0               Samyak/acsami.2c07557-supporting.pdf       CuGaTe2     Ag
# 0  Samyak/Adv Energy and Sustain Res - 2023 - Zha...       CuGaTe2     Sb
# 0  Samyak/Adv Material for Optics Elec - 1998 - M...       CuGaSe2    VCu
# 0  Samyak/Advanced Materials - 2012 - Plirdpring.pdf       CuGaTe2     Mn
# 0  Samyak/Aresti_1977_J._Electrochem._Soc._124_76...       CuGaTe2     Cd
# 0                              Samyak/BF00541585.pdf       CuGaTe2     NA
# 0                              Samyak/BF00541585.pdf       CuGaTe2     NA
# 0                                  Samyak/cugase.pdf       CuGaSe2     Mn
# 0                              Samyak/d0tc00795a.pdf       CuGaTe2     CP
# 0          Samyak/Zhang-2014-Enhancedthermoelect.pdf       CuGaTe2  Cu2Se
#
#    primiary_temperature primiary_duration primiary_ramp_rate  \
# 0                   870                NA                 NA
# 0                   298                NA                 NA
# 0                   298                NA                 NA
# 0                   973              94.0                 NA
# 0                   298                NA                 NA
# 0                  1100               5.0                 NA
# 0                   673              24.0              240.0
# 0                   298                NA                 NA
# 0                   298                NA                 NA
# 0                  1423              50.0                 NA
# 0                   298                NA                 NA
# 0                   298                NA                 NA
# 0                   298                NA                 NA
# 0                   298                NA                 NA
# 0                  1273               4.0                 NA
# 0                   298                NA                 NA
# 0                   298                NA                 NA
#
#    secondary_temperature secondary_duration secondary_ramp_rate  \
# 0                   1470                 NA                50.0
# 0                   1273               24.0                  NA
# 0                   1173               30.0                  NA
# 0                   1353               71.0                  NA
# 0                   1173               12.0                  NA
# 0                   1300                5.0                  NA
# 0                   1173               24.0                60.0
# 0                   1273               24.0                  NA
# 0                   1273               12.0                  NA
# 0                   1446                 NA                  NA
# 0                   1173                 NA                  NA
# 0                   1160               72.0                  NA
# 0                   1130                 NA                  NA
# 0                   1130                 NA                  NA
# 0                   1373                1.0                  NA
# 0                   1273               12.0               180.0
# 0                    859                 NA                  NA
#
#    annealing_temperature annealing_duration annealing_ramp_rate  \
# 0                    870              500.0                10.0
# 0                    773               72.0                  NA
# 0                    927               72.0                  NA
# 0                   1273               95.0                  NA
# 0                    873               12.0                  NA
# 0                    900              240.0                  NA
# 0                    923               96.0                30.0
# 0                    923                 NA                 2.0
# 0                    653           0.083333                  NA
# 0                   1373                 NA                  NA
# 0                    773               72.0                  NA
# 0                    298                 NA                  NA
# 0                    298                 NA                  NA
# 0                    298                 NA                  NA
# 0                    298                 NA                  NA
# 0                    298                 NA                  NA
# 0                    298                 NA                  NA
#
#   cooling_method         densification  pure_phase
# 0             NA                    NA           0
# 0      Quenching              HotPress           1
# 0             NA  SparkPlasmaSintering           1
# 0             NA                    NA           0
# 0           Room              HotPress           0
# 0             NA                    NA           0
# 0             NA              HotPress           1
# 0        Furnace  SparkPlasmaSintering           1
# 0      Quenching  SparkPlasmaSintering           0
# 0             NA                    NA           1
# 0        Furnace              HotPress           0
# 0   Icewaterbath                    NA           0
# 0             NA                    NA           0
# 0             NA                    NA           0
# 0      Quenching                    NA           0
# 0             NA              HotPress           1
# 0             NA                    NA           0

# %%
data_df_
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data_df.to_csv('result.csv')
data_df
