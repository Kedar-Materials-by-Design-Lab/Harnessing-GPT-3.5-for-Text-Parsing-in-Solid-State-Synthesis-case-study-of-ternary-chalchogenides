# %%
import os
import utils
import pandas as pd
key = 'API KEY'

#specify foldername here
for root, dirs, files in os.walk('Pritish'):
    break

# %%
data_df = pd.DataFrame()
# for ind, i in enumerate(files[5:]):
for ind, i in enumerate(files[0: ]):
    file_name = 'Pritish/' + i
    print(file_name)
    print(ind, 'of', len(files))
    print('-'*20)
    data_df = pd.concat([data_df, utils.extract_data_v2(file_name, key)])
    data_df.to_csv('result_' + str(i) + '.csv')
# Out:
# Pritish/PhysRevB.106.245303.pdf
# 0 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/PhysRevB.85.045130.pdf
# 1 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/PhysRevB.85.165125.pdf
# 2 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/PhysRevB.86.115208.pdf
# 3 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/PhysRevB.88.045202.pdf
# 4 of 20
# --------------------
# Synthesis info:
# Not specified
# YES
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
#
# Phase info:
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
#
# Base & Dopant info:
# ['Bi2Te3','Tl']
# ['Bi2Te3','Tl']
# ['Bi2Te3','Tl']
# ['NA','NA']
# ['Bi2Te3','Tl']
# ['Bi2Te3','Tl']
# ['Bi2Te3','Tl']
# ['NA','NA']
# ['Bi2Te3','Tl']
# ['Tl-doped Bi 2Te3','Tl']
#
# Temp Profile:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# NA | NA | NA | NA | NA | NA
#
# Check Profile format:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit | NA | NA | NA | NA | NA | NA
# Pritish/PhysRevB.88.214514.pdf
# 5 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/PhysRevB.89.085312.pdf
# 6 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/PhysRevB.93.085113.pdf
# 7 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/PhysRevB.93.165123.pdf
# 8 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/PhysRevLett.105.036404.pdf
# 9 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/PhysRevLett.105.216406.pdf
# 10 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/PhysRevLett.105.266401.pdf
# 11 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/PhysRevLett.107.097001.pdf
# 12 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/PhysRevLett.108.116801.pdf
# 13 of 20
# --------------------
# Synthesis info:
# Not specified
# YES
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
#
# Phase info:
# NA
# Yes
# NA
# NA
# NA
# NA
# NA
# NA
# NA
#
# Base & Dopant info:
# ['PbBiTe4','Sb']
# ['PbBiSbTe4', 'NA']
# ['PbBi2Te4', 'NA']
# ['PbBi2Te4','Sb']
# ['PbBi2Te4','NA']
# ['NA','NA']
# ['Pb(Bi1-xSbx)2Te4', 'Sb']
# ['NA','NA']
# ['PbBi2Te4','Sb']
#
# Temp Profile:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# 900 | /C | NA | NA | 1 | day
# 500 | /C | NA | NA | 4 | day
# NA | NA | 48 | /C per hour | NA | NA
#
# Check Profile format:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# 900 | /C | NA | NA | 1 | day
# 500 | /C | NA | NA | 4 | day
# NA | NA | 48 | /C per hour | NA | NA
#
# Cooling & Densification:
# ['NA', 'NA']
# Pritish/S0020168508100063.pdf
# 14 of 20
# --------------------
# Synthesis info:
# YES
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
#
# Phase info:
# NA
# No
# Not Specified
# NA
# NA
# NA
# NA
# NA
#
# Base & Dopant info:
# ['Tl2Te', 'Sn']
# ['Tl2Te', 'Sn']
# ['SnTe', 'TlBiTe2']
# ['NA','NA']
# ['NA','NA']
# ['NA','NA']
# ['NA','NA']
# ['NA','NA']
#
# Temp Profile:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# 698 | K | NA | NA | NA | NA
# 1080 | K | NA | NA | NA | NA
# 780 | K | NA | NA | NA | NA
# 830 | K | NA | NA | NA | NA
# 825 | K | NA | NA | NA | NA
#
# Check Profile format:
# """Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# 698 | K | NA | NA | NA | NA
# 1080 | K | NA | NA | NA | NA
# 780 | K | NA | NA | NA | NA
# 830 | K | NA | NA | NA | NA
# 825 | K | NA | NA | NA | NA"""
#
# Cooling & Densification:
# ['NA', 'NA']
# Pritish/S0020168514060065.pdf
# 15 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/S0021364010110111.pdf
# 16 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/S0036023611120254.pdf
# 17 of 20
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Pritish/s10853-021-06540-7.pdf
# 18 of 20
# --------------------
# Synthesis info:
# Not specified.
# Not specified
# Not specified
# Not specified
# Not specified

# %%
data_df.to_csv('result.csv')
data_df
