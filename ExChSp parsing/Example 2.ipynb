# %% [markdown]
# Import Libraries

# %%
import os
import utils
import pandas as pd

# %%
key = "API KEY"

# %%
import os

#specify foldername here
for root, dirs, files in os.walk('Batch 3 - Andy/Andy3_incomplete'):
    break
data_df = pd.DataFrame()

# %%
#for ind, i in enumerate(files[5:]):
for ind, i in enumerate(files):
    file_name = 'Batch 3 - Andy/Andy3_incomplete/' + i
    print(file_name)
    print(ind, 'of', len(files))
    print('-'*20)
    data_df = pd.concat([data_df, utils.extract_data_v2(file_name, key)])
# Out:
# Batch 3 - Andy/Andy3_incomplete/083302_1_online.pdf
# 0 of 8
# --------------------
# Synthesis info:
# Not specified
# YES
# YES
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
#
# Phase info:
# NA
# NA
# YES
# No
# NA
# NA
# NA
# NA
#
# Base & Dopant info:
# ['NA','NA']
# ['TlSbTe2','Cr']
# ['TlSbTe2','Cr']
# ['TlSbTe2','Cr']
# ['TlSbTe2','Cr']
# ['TlSbTe2','Cr']
# ['TlSbTe2','Cr']
# ['NA','NA']
#
# Temp Profile:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit
# NA | NA | NA | NA | NA | NA
#
# Check Profile format:
# Temperature | Temperature Unit | Temperature Ramp rate | Temperature Ramp Rate Unit | Duration | Duration Unit | NA | NA | NA | NA | NA | NA
# Batch 3 - Andy/Andy3_incomplete/10063843.pdf
# 1 of 8
# --------------------
# Synthesis info:
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# Not specified
# ...

# %%
data_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data_df.to_csv('result-a.csv')
data_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
